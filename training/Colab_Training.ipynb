# %% [markdown]
# # AI-Powered Predictive Crowd Panic Detection & Containment System
#
# This notebook provides the environment and execution steps to train the Multimodal AI on Google Colab using a GPU.

# %%
# !pip install kaggle
# !pip install torch torchvision torchaudio opencv-python
# !pip install ultralytics

# %% [markdown]
# Upload your `kaggle.json` here to authenticate and download datasets:

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !bash download_datasets.sh

# %%
# !python train.py
